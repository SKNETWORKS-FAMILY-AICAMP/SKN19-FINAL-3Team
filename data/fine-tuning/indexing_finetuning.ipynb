# %%
# !pip install -U transformers peft accelerate datasets bitsandbytes
# Out:
# Requirement already satisfied: transformers in /opt/anaconda3/envs/skn19_final/lib/python3.11/site-packages (4.57.3)
# Collecting peft
#   Downloading peft-0.18.0-py3-none-any.whl.metadata (14 kB)
# Collecting accelerate
#   Downloading accelerate-1.12.0-py3-none-any.whl.metadata (19 kB)
# Collecting datasets
#   Downloading datasets-4.4.2-py3-none-any.whl.metadata (19 kB)
# Collecting bitsandbytes
#   Using cached bitsandbytes-0.42.0-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/skn19_final/lib/python3.11/site-packages (from transformers) (3.20.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /opt/anaconda3/envs/skn19_final/lib/python3.11/site-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/envs/skn19_final/lib/python3.11/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/skn19_final/lib/python3.11/site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/envs/skn19_final/lib/python3.11/site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /opt/anaconda3/envs/skn19_final/lib/python3.11/site-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in /opt/anaconda3/envs/skn19_final/lib/python3.11/site-packages (from transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /opt/anaconda3/envs/skn19_final/lib/python3.11/site-packages (from transformers) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/anaconda3/envs/skn19_final/lib/python3.11/site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /opt/anaconda3/envs/skn19_final/lib/python3.11/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/envs/skn19_final/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/envs/skn19_final/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/anaconda3/envs/skn19_final/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: psutil in /opt/anaconda3/envs/skn19_final/lib/python3.11/site-packages (from peft) (7.2.1)
# Requirement already satisfied: torch>=1.13.0 in /opt/anaconda3/envs/skn19_final/lib/python3.11/site-packages (from peft) (2.2.2)
# Collecting pyarrow>=21.0.0 (from datasets)
#   Downloading pyarrow-22.0.0-cp311-cp311-macosx_12_0_x86_64.whl.metadata (3.1 kB)
# Collecting dill<0.4.1,>=0.3.0 (from datasets)
#   Using cached dill-0.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting pandas (from datasets)
#   Downloading pandas-2.3.3-cp311-cp311-macosx_10_9_x86_64.whl.metadata (91 kB)
# Requirement already satisfied: httpx<1.0.0 in /opt/anaconda3/envs/skn19_final/lib/python3.11/site-packages (from datasets) (0.28.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.6.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata (13 kB)
# Collecting multiprocess<0.70.19 (from datasets)
#   Downloading multiprocess-0.70.18-py311-none-any.whl.metadata (7.5 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<1.0,>=0.34.0->transformers)
#   Using cached fsspec-2025.10.0-py3-none-any.whl.metadata (10 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets)
#   Downloading aiohttp-3.13.3-cp311-cp311-macosx_10_9_x86_64.whl.metadata (8.1 kB)
# Requirement already satisfied: anyio in /opt/anaconda3/envs/skn19_final/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (4.12.0)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/skn19_final/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/skn19_final/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in /opt/anaconda3/envs/skn19_final/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/envs/skn19_final/lib/python3.11/site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: scipy in /opt/anaconda3/envs/skn19_final/lib/python3.11/site-packages (from bitsandbytes) (1.16.3)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets)
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting attrs>=17.3.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets)
#   Using cached attrs-25.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets)
#   Downloading frozenlist-1.8.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata (20 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets)
#   Downloading multidict-6.7.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets)
#   Downloading propcache-0.4.1-cp311-cp311-macosx_10_9_x86_64.whl.metadata (13 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets)
#   Downloading yarl-1.22.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata (75 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/skn19_final/lib/python3.11/site-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/skn19_final/lib/python3.11/site-packages (from requests->transformers) (2.6.2)
# Requirement already satisfied: sympy in /opt/anaconda3/envs/skn19_final/lib/python3.11/site-packages (from torch>=1.13.0->peft) (1.14.0)
# Requirement already satisfied: networkx in /opt/anaconda3/envs/skn19_final/lib/python3.11/site-packages (from torch>=1.13.0->peft) (3.6.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/skn19_final/lib/python3.11/site-packages (from torch>=1.13.0->peft) (3.1.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/skn19_final/lib/python3.11/site-packages (from jinja2->torch>=1.13.0->peft) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/skn19_final/lib/python3.11/site-packages (from pandas->datasets) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas->datasets)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->datasets)
#   Downloading tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/skn19_final/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/skn19_final/lib/python3.11/site-packages (from sympy->torch>=1.13.0->peft) (1.3.0)
# Downloading peft-0.18.0-py3-none-any.whl (556 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 556.4/556.4 kB 6.8 MB/s  0:00:00
# Downloading accelerate-1.12.0-py3-none-any.whl (380 kB)
# Downloading datasets-4.4.2-py3-none-any.whl (512 kB)
# Using cached dill-0.4.0-py3-none-any.whl (119 kB)
# Using cached fsspec-2025.10.0-py3-none-any.whl (200 kB)
# Downloading multiprocess-0.70.18-py311-none-any.whl (144 kB)
# Using cached bitsandbytes-0.42.0-py3-none-any.whl (105.0 MB)
# Downloading aiohttp-3.13.3-cp311-cp311-macosx_10_9_x86_64.whl (499 kB)
# Downloading multidict-6.7.0-cp311-cp311-macosx_10_9_x86_64.whl (44 kB)
# Downloading yarl-1.22.0-cp311-cp311-macosx_10_9_x86_64.whl (94 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached attrs-25.4.0-py3-none-any.whl (67 kB)
# Downloading frozenlist-1.8.0-cp311-cp311-macosx_10_9_x86_64.whl (50 kB)
# Downloading propcache-0.4.1-cp311-cp311-macosx_10_9_x86_64.whl (45 kB)
# Downloading pyarrow-22.0.0-cp311-cp311-macosx_12_0_x86_64.whl (36.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.0/36.0 MB 16.6 MB/s  0:00:02m0:00:0100:01
# Downloading pandas-2.3.3-cp311-cp311-macosx_10_9_x86_64.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 12.7 MB/s  0:00:00 eta 0:00:01
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Downloading xxhash-3.6.0-cp311-cp311-macosx_10_9_x86_64.whl (32 kB)
# Installing collected packages: pytz, xxhash, tzdata, pyarrow, propcache, multidict, fsspec, frozenlist, dill, attrs, aiohappyeyeballs, yarl, pandas, multiprocess, bitsandbytes, aiosignal, aiohttp, accelerate, peft, datasets
#   Attempting uninstall: fsspec90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/20 [pyarrow]
#     Found existing installation: fsspec 2025.12.0━━━━━━━━━━━━━  3/20 [pyarrow]
#     Uninstalling fsspec-2025.12.0:━━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/20 [pyarrow]
#       Successfully uninstalled fsspec-2025.12.0━━━━━━━━━━━━━━━  3/20 [pyarrow]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20/20 [datasets]/20 [datasets]e]s]
# Successfully installed accelerate-1.12.0 aiohappyeyeballs-2.6.1 aiohttp-3.13.3 aiosignal-1.4.0 attrs-25.4.0 bitsandbytes-0.42.0 datasets-4.4.2 dill-0.4.0 frozenlist-1.8.0 fsspec-2025.10.0 multidict-6.7.0 multiprocess-0.70.18 pandas-2.3.3 peft-0.18.0 propcache-0.4.1 pyarrow-22.0.0 pytz-2025.2 tzdata-2025.3 xxhash-3.6.0 yarl-1.22.0

# %%
model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    torch_dtype=torch.float16,
    device_map="auto",
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 model = AutoModelForCausalLM.from_pretrained(
#       2     MODEL_NAME,
#       3     torch_dtype=torch.float16,
#       4     device_map="auto",
#       5 )
#
# NameError: name 'AutoModelForCausalLM' is not defined
